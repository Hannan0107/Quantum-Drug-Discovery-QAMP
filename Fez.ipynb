# %%
# !pip install qiskit qiskit-ibm-runtime qiskit-algorithms pylatexenc qiskit-aer
# !pip install pandas scikit-learn matplotlib seaborn rdkit
# Out:
# Collecting qiskit
#   Downloading qiskit-2.3.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting qiskit-ibm-runtime
#   Downloading qiskit_ibm_runtime-0.45.0-py3-none-any.whl.metadata (21 kB)
# Collecting qiskit-algorithms
#   Downloading qiskit_algorithms-0.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit-ibm-runtime)
#   Downloading ibm_platform_services-0.73.1-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.12.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (25.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2 (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime)
#   Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (2026.1.4)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (43.0.3)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading pyspnego-0.12.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.23)
# Downloading qiskit-2.3.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 75.1 MB/s eta 0:00:00
# Downloading qiskit_ibm_runtime-0.45.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 49.6 MB/s eta 0:00:00
# Downloading qiskit_algorithms-0.4.0-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 23.5 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 77.7 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.73.1-py3-none-any.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.6/378.6 kB 30.1 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.3 MB/s eta 0:00:00
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.4 MB/s eta 0:00:00
# Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 4.9 MB/s eta 0:00:00
# Downloading pyspnego-0.12.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.3 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=91bbce55c9868a86cc74a20b33ad542a741d2ac1084be8fe66b9a3eed145b3f7
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, stevedore, rustworkx, qiskit, ibm_cloud_sdk_core, qiskit-algorithms, qiskit-aer, pyspnego, ibm-platform-services, requests-ntlm, qiskit-ibm-runtime
# Successfully installed ibm-platform-services-0.73.1 ibm_cloud_sdk_core-3.24.2 pylatexenc-2.10 pyspnego-0.12.0 qiskit-2.3.0 qiskit-aer-0.17.2 qiskit-algorithms-0.4.0 qiskit-ibm-runtime-0.45.0 requests-ntlm-1.3.0 rustworkx-0.17.1 stevedore-5.6.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
import requests
import io
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from rdkit import Chem
from rdkit.Chem import AllChem

from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as RuntimeSampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

warnings.filterwarnings('ignore')

EN_MAP = {'H': 2.20, 'Li': 0.98, 'Be': 1.57, 'B': 2.04, 'C': 2.55, 'N': 3.04, 'O': 3.44, 'F': 3.98, 'S': 2.58, 'Cl': 3.16}

def qmse_hero_normal(smiles):
    angle_scale = 0.1
    n_qubits = 12
    mol = Chem.MolFromSmiles(smiles)
    if not mol: return QuantumCircuit(n_qubits)

    atoms = [a for a in mol.GetAtoms()]
    qc = QuantumCircuit(n_qubits)

    n_exact = 10
    backbone = atoms[:n_exact]
    tail = atoms[n_exact:]
    mol_to_qubit = {atom.GetIdx(): i for i, atom in enumerate(backbone)}

    for atom in backbone:
        en = EN_MAP.get(atom.GetSymbol(), 1.0)
        qc.ry((en**2) * angle_scale, mol_to_qubit[atom.GetIdx()])

    if tail:
        tail_A = tail[0::2]
        tail_B = tail[1::2]
        if tail_A: qc.ry(sum(EN_MAP.get(a.GetSymbol(), 1.0) for a in tail_A) * (angle_scale/2), 10)
        if tail_B: qc.ry(sum(EN_MAP.get(a.GetSymbol(), 1.0) for a in tail_B) * (angle_scale/2), 11)

    for bond in mol.GetBonds():
        idx1, idx2 = bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()
        q1, q2 = mol_to_qubit.get(idx1), mol_to_qubit.get(idx2)

        b_type = bond.GetBondTypeAsDouble()

        if q1 is not None and q2 is not None:
            qc.rxx(b_type * 0.5, q1, q2)
        elif (q1 is not None):
            qc.rxx(0.5, q1, 10); qc.rxx(0.5, q1, 11)
        elif (q2 is not None):
            qc.rxx(0.5, q2, 10); qc.rxx(0.5, q2, 11)

    qc.measure_all()
    return qc

def extract_features(pub_result, n_qubits=12):
    c = pub_result.data.meas.get_counts()
    p = np.zeros(2**n_qubits)
    tot = sum(c.values())
    for k, v in c.items(): p[int(k, 2)] = v/tot
    return p

def print_metrics_table(name, y_true, y_pred, y_prob):
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    auc_val = roc_curve(y_true, y_prob)[1][1] if len(np.unique(y_true)) > 1 else 0.5
    print(f"    {name:10} | Acc: {acc:.1%} | Prec: {prec:.2f} | Rec: {rec:.2f} | F1: {f1:.2f} | AUC: {auc_val:.2f}")

def is_valid_mol(s):
    try: return Chem.MolFromSmiles(s) is not None
    except: return False


datasets = {}

try:
    print("\n1. Loading BBBP...")
    df = pd.read_csv("https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/BBBP.csv")
    df['target'] = df['p_np']
    df['SMILES'] = df['smiles']
    datasets['BBBP'] = df
except: print("   BBBP Load Failed")

try:
    print("2. Loading B3DB...")
    s = requests.get("https://raw.githubusercontent.com/theochem/B3DB/main/B3DB/B3DB_classification.tsv").content
    df = pd.read_csv(io.StringIO(s.decode('utf-8')), sep='\t')
    df['target'] = df['BBB+/BBB-'].map({'BBB+': 1, 'BBB-': 0})
    datasets['B3DB'] = df
except: print("    B3DB Load Failed")


token = "API"
instance = "CRN"
try:
    QiskitRuntimeService.save_account(token=token, channel="ibm_cloud", instance=instance, name="Name", overwrite=True)
except: pass

service = QiskitRuntimeService(name="Name")
backend = service.least_busy(operational=True, simulator=False, min_num_qubits=12)
print(f" Target Backend: {backend.name}")

results_store = {}

for name, df in datasets.items():
    print(f"\n" + "="*60)
    print(f" PROCESSING: {name} (Method: Normal + Bond Types)")
    print("="*60)

    df = df.dropna(subset=['target', 'SMILES'])
    df = df[df['SMILES'].apply(is_valid_mol)]
    df = df[df['SMILES'].str.len() < 70]

    df_pos = df[df['target'] == 1]
    df_neg = df[df['target'] == 0]

    n_sub = 125

    if len(df_pos) < n_sub or len(df_neg) < n_sub:
        print(f"Not enough data for {name}. Skipping.")
        continue

    df_final = pd.concat([df_pos.sample(n_sub, random_state=42), df_neg.sample(n_sub, random_state=42)]).sample(frac=1, random_state=42)
    y = df_final['target'].values
    smiles_list = df_final['SMILES'].values
    print(f"   Data Ready: {len(df_final)} molecules (Total 250).")

    print("   1. Generating Circuits (with Bond Logic)...")
    circuits = [qmse_hero_normal(s) for s in smiles_list]


    print("   2. Submitting to Hardware (1024 Shots)...")
    X_q_hw = None
    try:
        pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
        isa_circuits = pm.run(circuits)

        sampler_hw = RuntimeSampler(backend)
        sampler_hw.options.default_shots = 1024

        pubs = [(c,) for c in isa_circuits]

        job = sampler_hw.run(pubs)
        print(f"      ⏳ Job ID: {job.job_id()} (Waiting...)")
        result_hw = job.result()

        X_q_hw = []
        for pub in result_hw: X_q_hw.append(extract_features(pub))
        X_q_hw = np.array(X_q_hw)
        print("  Hardware Data Received.")
    except Exception as e:
        print(f" Hardware Failed: {e}")


    if X_q_hw is not None:

        X_c = np.array([np.array(AllChem.GetMorganFingerprintAsBitVect(Chem.MolFromSmiles(s), 2, nBits=256)) for s in smiles_list])


        sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        train_idx, test_idx = next(sss.split(X_c, y))

        print(f"\n  Split Info: Train Size = {len(train_idx)}, Test Size = {len(test_idx)}")
        print("\n   PERFORMANCE METRICS:")


        rf = RandomForestClassifier(n_estimators=100); rf.fit(X_c[train_idx], y[train_idx])
        res_c = (y[test_idx], rf.predict(X_c[test_idx]), rf.predict_proba(X_c[test_idx])[:, 1])
        print_metrics_table("Classical", *res_c)


        sc_h = StandardScaler()
        svc_h = SVC(kernel='rbf', C=10, probability=True)
        svc_h.fit(sc_h.fit_transform(X_q_hw[train_idx]), y[train_idx])
        res_h = (y[test_idx], svc_h.predict(sc_h.transform(X_q_hw[test_idx])), svc_h.predict_proba(sc_h.transform(X_q_hw[test_idx]))[:, 1])
        print_metrics_table("Hardware", *res_h)

        results_store[name] = {'Classical': res_c, 'Hardware': res_h}


print("\n" + "="*60)
print("GENERATING PLOTS")
print("="*60)

for name, res_dict in results_store.items():
    plt.figure(figsize=(14, 6))

    # ROC
    plt.subplot(1, 2, 1)
    colors = {'Classical': 'black', 'Hardware': 'red'}
    for model, (yt, yp, yprob) in res_dict.items():
        fpr, tpr, _ = roc_curve(yt, yprob)
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{model} (AUC={roc_auc:.2f})", color=colors.get(model, 'green'), linewidth=2)
    plt.plot([0,1],[0,1], 'k:')
    plt.title(f"{name}: ROC Curve")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # CM
    plt.subplot(1, 2, 2)
    cm = confusion_matrix(res_dict['Hardware'][0], res_dict['Hardware'][1])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', cbar=False,
                xticklabels=['Neg', 'Pos'], yticklabels=['Neg', 'Pos'])
    plt.title(f"{name}: Confusion Matrix (Hardware)")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")

    plt.tight_layout()
    plt.show()

print("\n EXPERIMENT COMPLETE.")
# Out:
# --- HERO REPLICATION RUN (Restoring Bond Logic) ---
#
# 1. Loading BBBP...
# 2. Loading B3DB...
#  Target Backend: ibm_fez
#
# ============================================================
#  PROCESSING: BBBP (Method: Normal + Bond Types)
# ============================================================
# [15:01:16] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:01:16] WARNING: not removing hydrogen atom without neighbors
# [15:01:16] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] Explicit valence for atom # 11 N, 4, is greater than permitted
# [15:01:17] Explicit valence for atom # 12 N, 4, is greater than permitted
# [15:01:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:01:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:01:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:01:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:01:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:17] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
# [15:01:18] WARNING: not removing hydrogen atom without neighbors
#    Data Ready: 250 molecules (Total 250).
#    1. Generating Circuits (with Bond Logic)...
#    2. Submitting to Hardware (1024 Shots)...
#       ⏳ Job ID: d5r30k65v3os73f3qi9g (Waiting...)
#   Hardware Data Received.
#
#   Split Info: Train Size = 200, Test Size = 50
#
#    PERFORMANCE METRICS:
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
# [15:03:02] DEPRECATION WARNING: please use MorganGenerator
#     Classical  | Acc: 66.0% | Prec: 0.70 | Rec: 0.56 | F1: 0.62 | AUC: 0.04
#     Hardware   | Acc: 86.0% | Prec: 0.82 | Rec: 0.92 | F1: 0.87 | AUC: 0.04
#
# ============================================================
#  PROCESSING: B3DB (Method: Normal + Bond Types)
# ============================================================
# [15:03:04] Explicit valence for atom # 10 C, 4, is greater than permitted
# [15:03:05] Explicit valence for atom # 10 C, 4, is greater than permitted
#    Data Ready: 250 molecules (Total 250).
#    1. Generating Circuits (with Bond Logic)...
#    2. Submitting to Hardware (1024 Shots)...
#       ⏳ Job ID: d5r31c8h0i0s73er2nag (Waiting...)
#   Hardware Data Received.
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:44] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
# [15:04:45] DEPRECATION WARNING: please use MorganGenerator
#   Split Info: Train Size = 200, Test Size = 50
#
#    PERFORMANCE METRICS:
#     Classical  | Acc: 76.0% | Prec: 0.74 | Rec: 0.80 | F1: 0.77 | AUC: 0.04
#     Hardware   | Acc: 44.0% | Prec: 0.42 | Rec: 0.32 | F1: 0.36 | AUC: 0.04
#
# ============================================================
# GENERATING PLOTS
# ============================================================
#  EXPERIMENT COMPLETE.
